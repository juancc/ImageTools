# %% [markdown]
# # SAM segmentation
# Image segmentation using Segment Anything Model (SAM)

# %%
D_NAME_TARGET = None#'set-green'

D_NAME_SRC = 'SASVAR_set'
SUB_DIRECTORY = 'NuevosProductos_crop'

# %% [markdown]
# # Preparation

# %%
import os
import sys
from pathlib import Path


import torch
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# !nvidia-smi
# Out:
# Wed Jun 14 19:13:55 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Instalation

# %%
HOME = os.getcwd()
print("HOME:", HOME)
# Out:
# HOME: /content

# %%
# !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/segment-anything.git'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/facebookresearch/segment-anything.git
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-errokiun
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-errokiun
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: segment-anything
#   Building wheel for segment-anything (setup.py) ... done
#   Created wheel for segment-anything: filename=segment_anything-1.0-py3-none-any.whl size=36589 sha256=67215a52d1f65f139108b6e3b9166b46676e68366fec9a5d9a986e90786a5a36
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gjocz7hl/wheels/10/cf/59/9ccb2f0a1bcc81d4fbd0e501680b5d088d690c6cfbc02dc99d
# Successfully built segment-anything
# Installing collected packages: segment-anything
# Successfully installed segment-anything-1.0

# %%
# Get pretrained weights
# !mkdir {HOME}/weights

# !wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth -P {HOME}/weights

CHECKPOINT_PATH = os.path.join(HOME, "weights", "sam_vit_h_4b8939.pth")
print(CHECKPOINT_PATH, ". Exist:", os.path.isfile(CHECKPOINT_PATH))
# Out:
# /content/weights/sam_vit_h_4b8939.pth . Exist: True

# %% [markdown]
# ## Load Model

# %%
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
MODEL_TYPE = "vit_h"

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)
mask_generator = SamAutomaticMaskGenerator(sam)

# %% [markdown]
# # Segment
#
# `SamAutomaticMaskGenerator` returns a `list` of masks, where each mask is a `dict` containing various information about the mask:
#
# * `segmentation` - `[np.ndarray]` - the mask with `(W, H)` shape, and `bool` type
# * `area` - `[int]` - the area of the mask in pixels
# * `bbox` - `[List[int]]` - the boundary box of the mask in `xywh` format
# * `predicted_iou` - `[float]` - the model's own prediction for the quality of the mask
# * `point_coords` - `[List[List[float]]]` - the sampled input point that generated this mask
# * `stability_score` - `[float]` - an additional measure of mask quality
# * `crop_box` - `List[int]` - the crop of the image used to generate this mask in `xywh` format

# %%
def blend(im1, im2, alpha):
    """Alpha blend"""
    return (1-alpha)*im1 + alpha*im2

def assemble_png(im, sam_mask):
    """Assemble PNG with mask from SAM"""
    alpha = np.zeros(sam_mask.shape)
    alpha[sam_mask] = 255
    mask = np.dstack([alpha for i in 'RGB']) / 255
    # Remove background
    bck = np.zeros(im.shape)+255
    src =  blend(bck, im, mask)

    return np.dstack([src, alpha])

def create_out_dir(path, tag='out'):
    output = path.split(os.sep)[-1]+f'_{tag}'

    output_dir = os.path.join(os.sep.join(path.split(os.sep)[:-1]), output)
    os.makedirs(output_dir, exist_ok=True)
    print(f'    - Output directory: {output_dir}')

    return output_dir

# %%
# Unzip source dataset
drive_path = f'/content/drive/MyDrive/SASVAR/waste_datasets/{D_NAME_SRC}.zip'
local_path = f'/content/{D_NAME_SRC}'
if not os.path.exists(local_path):
    # !unzip -qq {drive_path}

# %%
# Unzip target dataset
# Contains previously labeled
if D_NAME_TARGET:
    drive_path_target = f'/content/drive/MyDrive/{D_NAME_TARGET}.zip'
    local_path_target = f'/content/{D_NAME_TARGET}'
    if not os.path.exists(local_path_target):
        # !unzip -qq {drive_path_target}

# %%
# Check lready segmented images
sub_path = f'{local_path}/{SUB_DIRECTORY}'

src_files = list(Path(sub_path).glob('**/*'))

# Already segmented files
if D_NAME_TARGET:
    # Return the difference between source and target sets of filenames
    seg_files = Path(local_path_target).glob('**/*')

    src_filenames = set([f.name for f in src_files])
    trg_filenames = set([f.name for f in seg_files])

    print(f'{len(src_filenames)} source files | {len(trg_filenames)} target files')

    # Files to segment
    filenames = list(src_filenames.difference(trg_filenames))

    # Return again Path objects
    files = [f for f in src_files if f.name in filenames]
else:
    files = src_files

print(f'{len(files)} images to segment')
# Out:
# 261 images to segment

# %%
if D_NAME_TARGET:
    output_dir = local_path_target
else:
    output_dir = create_out_dir(sub_path)


err = []
for filepath in tqdm(files, total=len(files)):
    try:
        image_bgr = cv2.imread(str(filepath))
        image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
        sam_result = mask_generator.generate(image_rgb)
        # Sort image segments by area
        # Second largest segment is the target element
        # First is backgrund
        sam_result = sorted(sam_result, key=lambda item: item['area'], reverse=True)
        if len(sam_result) > 1:
            sam_mask = sam_result[1]['segmentation']

            # Assemble PNG file with segment
            out = assemble_png(image_bgr, sam_mask)

            out_filename = f'{filepath.name.split(".")[0]}.png'
            out_filepath = os.path.join(output_dir, out_filename)
            cv2.imwrite(out_filepath, out)

        else:
            err.append(str(filepath))


    except Exception as e:
        err.append(str(filepath))

print(f'{len(err)} Errors on images: {err}')
# Out:
#     - Output directory: /content/SASVAR_set/NuevosProductos_crop_out
# 100%|██████████| 261/261 [29:28<00:00,  6.78s/it]
# 0 Errors on images: []

# %% [markdown]
# # Compress and save

# %%
# !zip -r {D_NAME_TARGET}_out.zip {output_dir}
# Out:
#   adding: content/SASVAR_set/NuevosProductos_crop_out/ (stored 0%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_408_0_130623024607_0.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_145_0_130623003753_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_439_0_130623021830_2.png (deflated 9%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_693_0_130623012538_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_145_0_130623003753_1.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023747_0.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_651_0_130623025514_2.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_281_0_130623015915_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_683_0_130623015053_0.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_646_0_130623022141_1.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_697_0_130623014628_2.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_685_0_130623015029_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_674_0_130623013836_1.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_670_0_130623014803_1.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_654_0_130623022540_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_658_0_130623022024_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_439_0_130623021830_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023827_0.png (deflated 13%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_681_0_130623015716_1.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_192_0_130623025158_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_69_0_130623022458_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_265_0_130623012729_1.png (deflated 9%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_649_0_130623023649_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_68_0_130623025722_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_141_0_130623024352_0.png (deflated 13%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_684_0_130623015005_1.png (deflated 11%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_667_0_130623014740_0.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_650_0_130623025311_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023747_2.png (deflated 1%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_353_0_130623023529_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_145_0_130623003753_2.png (deflated 14%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_265_0_130623012729_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_145_0_130623022758_1.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_695_0_130623015214_1.png (deflated 9%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_215_0_130623023116_0.png (deflated 9%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_69_0_130623022458_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_47_0_130623025350_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_683_0_130623015053_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_700_0_130623005100_0.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_114_0_130623024117_2.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_147_0_130623003828_2.png (deflated 13%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_699_0_130623004950_2.png (deflated 1%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_403_0_130623024545_0.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_697_0_130623014628_1.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_281_0_130623015915_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_630_0_130623022103_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_192_0_130623025158_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_579_0_130623023606_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_662_0_130623022402_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_46_0_130623025440_2.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023827_1.png (deflated 23%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_665_0_130623014714_0.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_145_0_130623022758_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_695_0_130623015214_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_653_0_130623024318_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_146_0_130623012612_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_678_0_130623015804_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_137_0_130623024159_2.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_659_0_130623025555_0.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_691_0_130623013214_2.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_138_0_130623024222_2.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_681_0_130623015716_2.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023937_1.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_68_0_130623025722_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_146_0_130623012612_1.png (deflated 9%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_147_0_130623003828_1.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_649_0_130623023649_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_662_0_130623022402_2.png (deflated 10%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_659_0_130623025555_1.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_670_0_130623014803_2.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_265_0_130623012729_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_680_0_130623003644_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_657_0_130623021928_1.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_674_0_130623013836_0.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_375_0_130623024921_0.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_661_0_130623022632_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_660_0_130623023340_1.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_691_0_130623013214_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_695_0_130623015214_0.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_376_0_130623024709_1.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023841_1.png (deflated 20%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_685_0_130623015029_0.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023841_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_13_0_130623022247_2.png (deflated 10%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_662_0_130623022402_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_660_0_130623023340_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_657_0_130623021928_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_281_0_130623015915_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_657_0_130623021928_2.png (deflated 10%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_678_0_130623015804_1.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_670_0_130623013720_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_505_0_130623020034_1.png (deflated 10%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_692_0_130623012644_1.png (deflated 11%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_683_0_130623015053_1.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_679_0_130623003250_0.png (deflated 22%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_375_0_130623024921_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_689_0_130623004724_0.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_665_0_130623014714_1.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_677_0_130623003542_0.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_376_0_130623024709_2.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023747_1.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_576_0_130623012445_1.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_671_0_130623020127_1.png (deflated 11%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_511_0_130623030446_1.png (deflated 12%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_402_0_130623024459_0.png (deflated 9%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_661_0_130623022632_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_685_0_130623015029_1.png (deflated 9%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_675_0_130623004140_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_680_0_130623003644_1.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_58_0_130623030413_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_692_0_130623012644_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_13_0_130623022247_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_678_0_130623015804_2.png (deflated 9%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_677_0_130623003542_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_652_0_130623021751_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_376_0_130623024945_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_658_0_130623022024_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_46_0_130623025440_0.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_681_0_130623015716_0.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_663_0_130623023159_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_691_0_130623012926_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_408_0_130623024607_1.png (deflated 10%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_665_0_130623014714_2.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_403_0_130623024545_1.png (deflated 16%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_630_0_130623022103_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_645_0_130623022211_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_694_0_130623004800_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_511_0_130623030446_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_68_0_130623025804_1.png (deflated 10%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_653_0_130623024318_1.png (deflated 15%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_114_0_130623024117_0.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_675_0_130623004140_0.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_670_0_130623014803_0.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_651_0_130623025514_0.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_562_0_130623012812_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_684_0_130623015005_0.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_659_0_130623025555_2.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_376_0_130623024709_0.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_137_0_130623024159_0.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_67_0_130623025122_1.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_403_0_130623024545_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_667_0_130623014740_1.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_652_0_130623021751_2.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023921_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_663_0_130623023159_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_13_0_130623022247_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_689_0_130623004724_1.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_62_0_130623013537_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_646_0_130623022141_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_689_0_130623004724_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_670_0_130623013720_1.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_67_0_130623025122_2.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_653_0_130623024318_0.png (deflated 13%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_670_0_130623013720_2.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023841_0.png (deflated 17%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_655_0_130623022706_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_691_0_130623013214_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_680_0_130623003644_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_58_0_130623030413_1.png (deflated 11%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_677_0_130623003542_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_46_0_130623025440_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623024021_2.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_655_0_130623022706_1.png (deflated 12%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_671_0_130623020127_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_647_0_130623023303_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_667_0_130623014740_2.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_505_0_130623020034_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_67_0_130623025122_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_676_0_130623003412_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_676_0_130623003412_1.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_375_0_130623024830_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623024021_0.png (deflated 1%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023937_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_62_0_130623013537_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_691_0_130623012926_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_375_0_130623024830_0.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_675_0_130623004140_1.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_402_0_130623024459_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023827_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023921_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_192_0_130623025158_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_562_0_130623012812_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_645_0_130623022211_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_700_0_130623005100_1.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_647_0_130623023303_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_630_0_130623022103_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_137_0_130623024159_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_658_0_130623022024_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_353_0_130623023529_2.png (deflated 9%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_62_0_130623013537_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_138_0_130623024222_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_68_0_130623025804_0.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_655_0_130623022706_0.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_671_0_130623020127_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_69_0_130623022458_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_47_0_130623025350_0.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_649_0_130623023649_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_585_0_130623022325_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_684_0_130623015005_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_215_0_130623023116_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_693_0_130623012538_1.png (deflated 9%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_215_0_130623023116_1.png (deflated 10%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_673_0_130623004050_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_562_0_130623012812_1.png (deflated 10%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_114_0_130623024117_1.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_650_0_130623025311_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_660_0_130623023340_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_651_0_130623025514_1.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_585_0_130623022325_1.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_652_0_130623021751_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_576_0_130623012445_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_694_0_130623004800_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_661_0_130623022632_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_141_0_130623024352_1.png (deflated 16%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_646_0_130623022141_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_699_0_130623004950_1.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_585_0_130623022325_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_353_0_130623023529_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023921_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_47_0_130623025350_2.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_402_0_130623024459_1.png (deflated 11%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_376_0_130623024945_1.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_511_0_130623030446_2.png (deflated 9%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_145_0_130623022758_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_691_0_130623012926_1.png (deflated 12%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_697_0_130623014628_0.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_141_0_130623024352_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_408_0_130623024607_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_58_0_130623030413_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_673_0_130623004050_2.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_439_0_130623021830_1.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_579_0_130623023606_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_663_0_130623023159_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_645_0_130623022211_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_138_0_130623024222_0.png (deflated 2%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_505_0_130623020034_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_673_0_130623004050_1.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_700_0_130623005100_2.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_654_0_130623022540_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_676_0_130623003412_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_375_0_130623024921_1.png (deflated 10%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_674_0_130623013836_2.png (deflated 3%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_68_0_130623025804_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_694_0_130623004800_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623024021_1.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_650_0_130623025311_2.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_647_0_130623023303_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_375_0_130623024830_2.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_654_0_130623022540_2.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_579_0_130623023606_1.png (deflated 7%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_576_0_130623012445_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_376_0_130623024945_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_679_0_130623003250_1.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_68_0_130623025722_0.png (deflated 4%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_692_0_130623012644_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_648_0_130623023937_0.png (deflated 5%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_147_0_130623003828_0.png (deflated 6%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_693_0_130623012538_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_679_0_130623003250_2.png (deflated 11%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_146_0_130623012612_2.png (deflated 8%)
#   adding: content/SASVAR_set/NuevosProductos_crop_out/O_699_0_130623004950_0.png (deflated 2%)

# %%
# !cp {D_NAME_TARGET}_out.zip /content/drive/MyDrive/
